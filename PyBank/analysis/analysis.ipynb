# %%
import os
import csv


#analysis_csv = os.path.join('.','resources','budget_data.csv')
analysis_csv = os.path.join('.','resources','budget_data.csv')


with open(analysis_csv, 'r') as csvfile:

    csvreader = csv.reader(csvfile, delimiter=',')
    next(csvreader)
    #print(csvreader)
    for row in csvreader:
        print(row)
    #header = next(csvreader)

total_months = len(data)
total_profit_losses = sum(data.values())

#print(f"Total number of months: {total_months}")
#print(f"Total Profit/Losses: ${total_profit_losses}")

changes = []
previous_value = None

for month, value in data.items():
    if previous_value is not None:
        change = value - previous_value
        changes.append(change)
    previous_value = value

# Calculate average of changes
average_change = sum(changes) / len(changes)

#print(f"Changes in Profit/Losses over the entire period: {changes}")
#print(f"Average of changes: ${average_change:.2f}")

max_increase = 0
max_increase_month = ""
max_decrease = 0
max_decrease_month = ""
previous_value = None

for month, value in data.items():
    if previous_value is not None:
        change = value - previous_value
        if change > max_increase:
            max_increase = change
            max_increase_month = month
        if change < max_decrease:
            max_decrease = change
            max_decrease_month = month
    previous_value = value

analysis = (
    f"Total number of months: {total_months}\n"
    f"Total Profit/Losses: ${total_profit_losses}\n"
    f"Average of changes: ${average_change:.2f}\n"
    f"The greatest increase in profits occurred in {max_increase_month} with ${max_increase}"
    f"The greatest decrease in profits occurred in {max_decrease_month} with ${max_decrease}")

print(analysis)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[132], line 9
#       5 #analysis_csv = os.path.join('.','resources','budget_data.csv')
#       6 analysis_csv = os.path.join('.','resources','budget_data.csv')
# ----> 9 with open(analysis_csv, 'r') as csvfile:
#      11     csvreader = csv.reader(csvfile, delimiter=',')
#      12     next(csvreader)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# ...

# %%
import os
import csv

analysis_csv = os.path.join('.','resources','budget_data.csv')

with open (analysis_csv,'r') as csv_file:
   read_content = csv.reader(csv_file)
   next(read_content)
   for row in read_content:
     print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[138], line 6
#       2 import csv
#       4 analysis_csv = os.path.join('.','resources','budget_data.csv')
# ----> 6 with open (analysis_csv,'r') as csv_file:
#       7    read_content = csv.reader(csv_file)
#       8    next(read_content)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.\\resources\\budget_data.csv'

# %%
import os
import csv

#csv_path = os.path.join(".", "Resources", "budget_data.csv")
#csv_path = r "C:\Users\nprab\OneDrive\Desktop\repos\python-challenge\PyBank\resources.csv"
csv_path = r"C:\Users\nprab\OneDrive\Desktop\repos\python-challenge\PyBank\resources\budget_data.csv"

with open(csv_path,'r') as csv_file:
   read_content = csv.reader(csv_file,delimiter=',')
   next(read_content)
    
   for row in read_content: 
     print(row)


total_months = len(csv_path)
print(f"Total number of months: {total_months}")
# Out:
# ['Jan-10', '1088983']
# ['Feb-10', '-354534']
# ['Mar-10', '276622']
# ['Apr-10', '-728133']
# ['May-10', '852993']
# ['Jun-10', '563721']
# ['Jul-10', '-535208']
# ['Aug-10', '632349']
# ['Sep-10', '-173744']
# ['Oct-10', '950741']
# ['Nov-10', '-785750']
# ['Dec-10', '-1194133']
# ['Jan-11', '-589576']
# ['Feb-11', '-883921']
# ['Mar-11', '443564']
# ['Apr-11', '837887']
# ['May-11', '1081472']
# ['Jun-11', '464033']
# ['Jul-11', '-1066544']
# ['Aug-11', '323846']
# ['Sep-11', '-806551']
# ['Oct-11', '487053']
# ['Nov-11', '1128811']
# ['Dec-11', '791398']
# ['Jan-12', '739367']
# ['Feb-12', '-197825']
# ['Mar-12', '666016']
# ['Apr-12', '589771']
# ['May-12', '489290']
# ['Jun-12', '-471439']
# ['Jul-12', '120417']
# ['Aug-12', '175347']
# ['Sep-12', '855449']
# ['Oct-12', '605195']
# ['Nov-12', '-235220']
# ['Dec-12', '347138']
# ['Jan-13', '298510']
# ['Feb-13', '163254']
# ['Mar-13', '1141840']
# ['Apr-13', '542630']
# ['May-13', '99841']
# ['Jun-13', '752765']
# ...

# %%
import os
import csv
data = "C:\\Users\\nprab\\Downloads\\Starter_Code (2)\\Starter_Code\\PyBank\\Resources\\budget_data.csv"

with open(data ,'r') as csv:
    print(csv)

    lines = csv.read()
    print(lines)

total_months = len(data)  #data=csv_path
print(f"Total number of months: {total_months}")





# Calculate the total profit/losses
total_profit_losses = sum(data.values())

# Create a dictionary with the total profit/losses
result_dict = {"Total Profit/Losses": total_profit_losses}

# Convert the dictionary into a list
result_list = [result_dict]

print(result_list)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\nprab\\Downloads\\Starter_Code (2)\\Starter_Code\\PyBank\\Resources\\budget_data.csv' mode='r' encoding='cp1252'>
# Date,Profit/Losses
# Jan-10,1088983
# Feb-10,-354534
# Mar-10,276622
# Apr-10,-728133
# May-10,852993
# Jun-10,563721
# Jul-10,-535208
# Aug-10,632349
# Sep-10,-173744
# Oct-10,950741
# Nov-10,-785750
# Dec-10,-1194133
# Jan-11,-589576
# Feb-11,-883921
# Mar-11,443564
# Apr-11,837887
# May-11,1081472
# Jun-11,464033
# Jul-11,-1066544
# Aug-11,323846
# Sep-11,-806551
# Oct-11,487053
# Nov-11,1128811
# Dec-11,791398
# Jan-12,739367
# Feb-12,-197825
# Mar-12,666016
# Apr-12,589771
# May-12,489290
# Jun-12,-471439
# Jul-12,120417
# Aug-12,175347
# Sep-12,855449
# Oct-12,605195
# Nov-12,-235220
# Dec-12,347138
# Jan-13,298510
# Feb-13,163254
# Mar-13,1141840
# Apr-13,542630
# May-13,99841
# Jun-13,752765
# Jul-13,-252949
# Aug-13,914424
# Sep-13,679524
# Oct-13,514377
# Nov-13,462102
# Dec-13,159782
# Jan-14,878810
# Feb-14,-946748
# ...

# %%
csvpath = os.path.join(".", "Resources", "budget_data.csv")
with open(csvpath) as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    print(csvreader)

    # Read the header row first (skip this step if there is now header)
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")

    # Read each row of data after the header
    for row in csvreader:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 2
#       1 csvpath = os.path.join(".", "Resources", "budget_data.csv")
# ----> 2 with open(csvpath) as csvfile:
#       3
#       4     # CSV reader specifies delimiter and variable that holds contents
#       5     csvreader = csv.reader(csvfile, delimiter=',')
#       7     print(csvreader)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# ...

# %%
import os
import csv
csv_path = "C:\\Users\\nprab\\Downloads\\Starter_Code (2)\\Starter_Code\\PyBank\\Resources\\budget_data.csv"

with open(csv_path ,'r') as csv:
    print(csv)

    lines = csv.read()
    print(lines)

import os
import csv
csv_path = "C:\\Users\\nprab\\Downloads\\Starter_Code (2)\\Starter_Code\\PyBank\\Resources\\budget_data.csv"

with open(csv_path,'r') as csv_file:
   read_content = csv.reader(csv_file,delimiter=',')
   next(read_content)
    
   for row in read_content: 
     print(row)
